# %% [markdown]
# # <font color = "red">[READ THIS] Before you start</font>
# Welcome to UpLevel mini-projects! In this series, you're challenged to independently work (with our guidance) with data that you will collect to UpLevel yourself.
#
# We hope you're excited to embark on this adventure.
# ### Warning:
# This isn't just any coding course or programmes, where you receive helper code as you move from one code block to another.
#
# This is when things get <em>real</em>.
#
# In this project, you will receive instructions to execute a task along with an intended outcome. Most importantly, we will provide you with directions you can go to, to pick up code independently and implement it in this notebook.
#
# Don't worry though, we'll be dropping lots of resources you can consult and these readings will contain everything you need to succeed. You can also perform independent research to find answers independently. You just have to read closely and pick out the parts that make most sense.
#
# <strong>We make you do this not because we're lazy bastards but because being able to indepedently find code is a highly underrated skill and that's something all companies look out for.</strong>
#
# If you're really stuck and are on the verge of giving up, we gotchu fam. Head on over to https://www.facebook.com/UpLevelSG/ and post your questions there.
#
# ### What we'll be doing:
# In this project, we will do the following:
#
# 1. Download and collect data (Part I)
# 2. Perform data combination and cleaning (Part II)
# 3. Perform data analysis and visualization (Part III)
#
# ### Expectations:
# We're not going to sugarcoat it - it'll be challenging at times. You have to promise to put in the time and effort to UpLevel yourself.
#
# But we promise you that it'll ultimately be fun and rewarding, and you'll come out of it stronger and more confident than before.

# %% [markdown]
# # Introduction
#
# Dogs are awesome creatures.
#
# Touted as Man's best friend, dogs descended from wolves and have lived with humans over literally thousands of years. Through selective breeding, we see over a hundred breeds today.
#
# These breeds come in all sizes, shapes, and even intelligence. But inevitably, some breeds end up more popular than others. Why is that so? In this project series, we attempt to answer it using different pieces of data.
#
# First up, we obtain the intelligence data from a research conducted by Cohen in 1994. His work is described in Wikipedia: https://en.wikipedia.org/wiki/The_Intelligence_of_Dogs.
#
# We will also use the American Kennel Club's (AKC) data. AKC is the authority in dog breed research, and regularly updates its website with data that one can refer to.
#
# In this project series, we combine several datasets to test the following hypotheses:
# 1. Intelligent dogs are more popular than non-intelligent dogs
# 2. Big dogs are more popular than small dogs
# 3. Size is correlated to intelligence of the dogs
#
# ### Rationale for working with this dataset
# Understandably, this dataset is relatively small if you come from a background that involves four digits' rows worth of data and more.
#
# However, the important thing is that you can/should learn to tell a good data story no matter the dataset.
#
# We guarantee you that you'll enjoy examining doggo data, and obtain fun insights that you can tell your friends, family, and most importantly - your would-be employers.

# %% [markdown]
# ### Step 1: Import your library
# For this, you will import only the following library:
# 1. pandas as pd

# %%
# Step 1: Import your library
import pandas as pd

# %% [markdown]
# ### Step 2: Get the first dataset
# We took the liberty of getting the organized data up for you.
#
# Download the data here from our server: <a href="https://uplevelsg.s3-ap-southeast-1.amazonaws.com/ProjectDoggoIntelligence/dog_intelligence.csv">link</a>.
#
# The data is organized from the Wikipedia article shown above, but you're free to also make your own dataset manually instead of downloading it below.
#
# ### Step 3: Read the downloaded CSV as a DataFrame
# After downloading the data, read the CSV as a DataFrame.

# %%
# Step 3: Read the downloaded CSV as a DataFrame
df = pd.read_csv('/Users/sm/Desktop/CourseMaterials/dog_intelligence.csv')
df
# Out:
#                  breed                                    classification  \
# 0        Border Collie                                    Brightest Dogs
# 1               Poodle                                    Brightest Dogs
# 2      German Shepherd                                    Brightest Dogs
# 3     Golden Retriever                                    Brightest Dogs
# 4    Doberman Pinscher                                    Brightest Dogs
# ..                 ...                                               ...
# 131             Borzoi  Lowest Degree of Working/Obedience Intelligence
# 132          Chow Chow  Lowest Degree of Working/Obedience Intelligence
# 133            Bulldog  Lowest Degree of Working/Obedience Intelligence
# 134            Basenji  Lowest Degree of Working/Obedience Intelligence
# 135       Afghan Hound  Lowest Degree of Working/Obedience Intelligence
#
#     obey_rate  lower_reps  upper_reps
# 0         95%           1           4
# ...

# %% [markdown]
# ### Step 4: Check for missing data
# Check for NaN in your DataFrame to see if there is any missing data.
#
# <strong>Hint: Google "check missing data pandas"</strong>

# %%
# Step 4: Check for missing data in DataFrame
df.isnull().sum(axis=0)
# Out:
# breed              0
# classification     0
# obey_rate         11
# lower_reps         0
# upper_reps         0
# dtype: int64

# %% [markdown]
# ### Step 5: Replace NaN with "0%"
# Looks like there isn't many missing data in the DataFrame. We'll go ahead with replacing the NaN with "0%" for the column "obey_rate".
#
# Since it's a small dataset, there are two ways to do it:
# 1. Open the file in Excel, and enter the empty fields manually with "%0"
# 2. Use fillna to replace NaN with "0%"

# %%
# Step 5: Replace NaN with "0%"
df.fillna("0%", inplace=True)
df.isnull().sum(axis=0)
# Out:
# breed             0
# classification    0
# obey_rate         0
# lower_reps        0
# upper_reps        0
# dtype: int64

# %% [markdown]
# ### Step 6: Export the DataFrame as CSV
# Now that you've edited the DataFrame and replaced the NaN values, export them as a CSV for Part II later.

# %%
# Step 6: Export the DataFrame as CSV
df.to_csv('dog_intelligence v2.csv',index=None)

# %% [markdown]
# ### Step 7: Collect dog weight data from American Kennel Club
# We've downloaded our first dataset, and now we will move on to retrieve the dog weight data from the American Kennel Club website at: https://www.akc.org/expert-advice/nutrition/breed-weight-chart/
#
# ![AKCWebsite.png](attachment:AKCWebsite.png)
#
# Highlight the word "Breed" and drag your mouse all the way to the bottom right corner, highlightining all of the elements in the table.
#
# ![HighlightingAKCData.png](attachment:HighlightingAKCData.png)
#
# Open your favorite spreadsheet software and paste it there.
#
# ![PasteTableData.png](attachment:PasteTableData.png)
#
# Sanity check for your copied data:
# 1. Cell A1: Breed
# 2. Cell A190 (or the last cell): Yorkshire
# 3. 3 columns of data only
# 4. Around 190 rows (a rough estimate in case new breeds emerge in the future)
#
# Make sure when you paste, you paste "Match Destination Formatting" so that you get text only.
#
# <font color = "red">Save the Excel file afterwards in the same directory as a CSV UTF-8 file.</font>
#
# You'd be surprised how easy it is compared to building a scraper from scratch.</strong>
#
# Alternatively, if the website is down or no longer available, download the data from our server: <a href = "https://uplevelsg.s3-ap-southeast-1.amazonaws.com/ProjectDoggoIntelligence/breedweight.csv">link</a>.
#
# <strong>Hot tip: If you see a table on a website that you want to copy only once, try to highlight and copy+paste onto Excel.

# %% [markdown]
# ### Step 8: Collect dog popularity rankng from American Kennel Club
# Repeat the same data collection step from the table found in here: https://www.akc.org/expert-advice/news/most-popular-dog-breeds-full-ranking-list/
#
# You should have the following data in your sheet:
# 1. 6 columns
# 2. 193 rows
# 3. Ranks for breeds from 2014 - 2018
#
# Alternatively, if the website is down or no longer available, download the data from our server: <a href = "https://uplevelsg.s3-ap-southeast-1.amazonaws.com/ProjectDoggoIntelligence/breedpopularity.csv">link</a>

# %% [markdown]
# ### End of Part I
# By now, you should have three datasets:
# 1. Dog intelligence from Wikipedia (prepared by us)
# 2. Dog weight data from American Kennel Club (prepared by you)
# 3. Dog popularity data from American Kennel Club (prepared by you)
#
# Next in Part II, we will be stitching the data together.
